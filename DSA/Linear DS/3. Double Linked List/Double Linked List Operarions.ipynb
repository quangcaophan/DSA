# %%
# Append
class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    # create doubly linked list
    def create_linked_list(self):
        # add first node
        node1 = Node(80)
        # both head and tail is the first node
        self.head = node1
        self.tail = node1

        # add second node
        node2 = Node(9)
        # update the pointers
        node1.next = node2
        node2.prev = node1
        # node2 becomes the new tail
        self.tail = node2

        # add third node
        node3 = Node(14)
        # update the pointers
        node2.next = node3
        node3.prev = node2
        # node3 becomes the new tail
        self.tail = node3
    
    #  traverse the linked list
    def traverse(self):
        # start at head
        current = self.head
        print("None", end = " <-> ")
        # loop until the node is None
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")
    # reverse traverse the linked list
    def reverse_traverse(self):
        # start at tail
        current = self.tail
        print("None", end = " <-> ")
        # loop until node is None
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")

    # insert at the end(append)
    def append(self, data):
        # initialize a new node
        new_node = Node(data)
        # update link
        new_node.prev = self.tail
        self.tail.next = new_node
        #  update tail
        self.tail = new_node

linked_list = DoublyLinkedList()
linked_list.create_linked_list()
linked_list.traverse()
linked_list.append(20)
linked_list.traverse()
# Out:
# None <-> 80 <-> 9 <-> 14 <-> None
# None <-> 80 <-> 9 <-> 14 <-> 20 <-> None

# %%
# Append Element

class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    # create doubly linked list
    def create_linked_list(self):
        # add first node
        node1 = Node(80)
        # both head and tail is the first node
        self.head = node1
        self.tail = node1

        # add second node
        node2 = Node(9)
        # update the pointers
        node1.next = node2
        node2.prev = node1
        # node2 becomes the new tail
        self.tail = node2

        # add third node
        node3 = Node(14)
        # update the pointers
        node2.next = node3
        node3.prev = node2
        # node3 becomes the new tail
        self.tail = node3
    
    #  traverse the linked list
    def traverse(self):
        # start at head
        current = self.head
        print("None", end = " <-> ")
        # loop until the node is None
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")

    # reverse traverse the linked list
    def reverse_traverse(self):
        # start at tail
        current = self.tail
        print("None", end = " <-> ")
        # loop until node is None
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")

    # check if empty
    def is_empty(self):
        return self.head == None

    # append to empty list
    def append_to_empty(self, data):
        new_node = Node(data)
        self.head = new_node
        self.tail = new_node

    # insert at the end(append)
    def append(self, data):
        # check if empty
        if self.is_empty():
            self.append_to_empty(data)
            return
        # initialize a new node
        new_node = Node(data)
        # update link
        new_node.prev = self.tail
        self.tail.next = new_node
        #  update tail
        self.tail = new_node

linked_list = DoublyLinkedList()
# linked_list.create_linked_list()
# linked_list.traverse()
linked_list.append(20)
linked_list.traverse()
# Out:
# None <-> 20 <-> None

# %% [markdown]
# # Time Complexity for Append
# Appending in a doubly linked list doesn't require any traversal of the list. Hence,
#
# Time Complexity: O(1)

# %%
# Insert at the Beginning
class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    #  traverse the linked list
    def traverse(self):
        current = self.head
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")

    # reverse traverse the linked list
    def reverse_traverse(self):
        current = self.tail
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")

    # check if empty
    def is_empty(self):
        return self.head == None

    # append to empty list
    def append_to_empty(self, data):
        new_node = Node(data)
        self.head = new_node
        self.tail = new_node

    # insert at the end(append)
    def append(self, data):
        if self.is_empty():
            self.append_to_empty(data)
            return
        new_node = Node(data)
        new_node.prev = self.tail
        self.tail.next = new_node
        self.tail = new_node
    
    # insert at beginning
    def insert_at_beginning(self, data):
        # check if the list is empty
        if self.is_empty():
            self.append_to_empty()
            return
        # create new node
        new_node = Node(data)

        # update pointers
        new_node.next = self.head
        self.head.prev = new_node

        # update head
        self.head = new_node
        
linked_list = DoublyLinkedList()
linked_list.append(80)
linked_list.append(9)
linked_list.append(14)
linked_list.traverse()
linked_list.insert_at_beginning(10)
linked_list.traverse()

# %% [markdown]
# # Time Complexity for Insert at the Beginning
# Insertion at the Beginning can directly access the head pointer. Hence,
#
# Time Complexity: O(1)

# %%
# Insert at a Given Position

class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    #  traverse the linked list
    def traverse(self):
        current = self.head
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")

    # reverse traverse the linked list
    def reverse_traverse(self):
        current = self.tail
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")
    # node count
    def node_count(self):
        current = self.head
        count = 0
        while current is not None:
            count += 1
            current = current.next
        return count

    # check if empty
    def is_empty(self):
        return self.head == None

    # append to empty list
    def append_to_empty(self, data):
        new_node = Node(data)
        self.head = new_node
        self.tail = new_node

    # insert at the end(append)
    def append(self, data):
        if self.is_empty():
            self.append_to_empty(data)
            return
        new_node = Node(data)
        new_node.prev = self.tail
        self.tail.next = new_node
        self.tail = new_node
    
    # insert at beginning
    def insert_at_beginning(self, data):
        if self.is_empty():
            self.append_to_empty()
            return
        new_node = Node(data)
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node
    
    # insert at position
    def insert_at_position(self, position, data):
        # check if position is valid
        if position < 0 or position > self.node_count():
            print("Invalid position")
            return
        # if position is 1, perform insert at beginning
        elif position == 0:
            self.insert_at_beginning(data)
            return
        # if position = number of nodes, insert at the end
        elif position == self.node_count():
            self.append(data)
            return
        else:
            # create new node
            new_node = Node(data)
            # bring a pointer to desired position 
            current = self.head
            for i in range(position - 1):
                current = current.next
            # get a pointer to the next node
            next_node = current.next

            # update pointers
            current.next = new_node
            next_node.prev = new_node

            new_node.prev = current
            new_node.next = next_node

        
linked_list = DoublyLinkedList()
linked_list.append(80)
linked_list.append(9)
linked_list.append(14)
linked_list.traverse()
linked_list.insert_at_position(2, 11)
linked_list.traverse()

# %% [markdown]
# # Time Complexity for Insertion at Given Position
# Insertion at Given Position depends on the position and you may need to traverse the entire list. Hence,
#
# Time Complexity: O(n)
#
# Next, we will learn about deleting from a circular linked list.

# %%
# Delete First Node

class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    #  traverse the linked list
    def traverse(self):
        current = self.head
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")

    # reverse traverse the linked list
    def reverse_traverse(self):
        current = self.tail
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")
    # node count
    def node_count(self):
        current = self.head
        count = 0
        while current is not None:
            count += 1
            current = current.next
        return count

    # check if empty
    def is_empty(self):
        return self.head == None

    # append to empty list
    def append_to_empty(self, data):
        new_node = Node(data)
        self.head = new_node
        self.tail = new_node

    # insert at the end(append)
    def append(self, data):
        if self.is_empty():
            self.append_to_empty(data)
            return
        new_node = Node(data)
        new_node.prev = self.tail
        self.tail.next = new_node
        self.tail = new_node
    
    # insert at beginning
    def insert_at_beginning(self, data):
        if self.is_empty():
            self.append_to_empty()
            return
        new_node = Node(data)
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node
    
    # insert at position
    def insert_at_position(self, position, data):
        if position < 0 or position > self.node_count():
            print("Invalid position")
            return
        elif position == 0:
            self.insert_at_beginning(data)
            return
        elif position == self.node_count():
            self.append(data)
            return
        else:
            new_node = Node(data)
            current = self.head
            for i in range(position - 1):
                current = current.next
            next_node = current.next
            current.next = new_node
            next_node.prev = new_node
            new_node.prev = current
            new_node.next = next_node

    # delete from beginning
    def delete_from_beginning(self):
        # check if empty:
        if self.is_empty():
            print('Cannot delete from Empty')
            return
        # get reference to the head node
        current = self.head
        # shift head
        self.head = self.head.next
        # update prev of head
        self.head.prev = None
        # delete node
        del current
        
linked_list = DoublyLinkedList()
linked_list.append(10)
linked_list.append(80)
linked_list.append(9)
linked_list.append(11)
linked_list.append(14)
linked_list.traverse()
linked_list.delete_from_beginning()
linked_list.traverse()
# Out:
# None <-> 10 <-> 80 <-> 9 <-> 11 <-> 14 <-> None
# None <-> 80 <-> 9 <-> 11 <-> 14 <-> None

# %%
# Delete Only Node

class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    #  traverse the linked list
    def traverse(self):
        current = self.head
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")

    # reverse traverse the linked list
    def reverse_traverse(self):
        current = self.tail
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")
    # node count
    def node_count(self):
        current = self.head
        count = 0
        while current is not None:
            count += 1
            current = current.next
        return count

    # check if empty
    def is_empty(self):
        return self.head == None

    # append to empty list
    def append_to_empty(self, data):
        new_node = Node(data)
        self.head = new_node
        self.tail = new_node

    # insert at the end(append)
    def append(self, data):
        if self.is_empty():
            self.append_to_empty(data)
            return
        new_node = Node(data)
        new_node.prev = self.tail
        self.tail.next = new_node
        self.tail = new_node
    
    # insert at beginning
    def insert_at_beginning(self, data):
        if self.is_empty():
            self.append_to_empty()
            return
        new_node = Node(data)
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node
    
    # insert at position
    def insert_at_position(self, position, data):
        if position < 0 or position > self.node_count():
            print("Invalid position")
            return
        elif position == 0:
            self.insert_at_beginning(data)
            return
        elif position == self.node_count():
            self.append(data)
            return
        else:
            new_node = Node(data)
            current = self.head
            for i in range(position - 1):
                current = current.next
            next_node = current.next
            current.next = new_node
            next_node.prev = new_node
            new_node.prev = current
            new_node.next = next_node

    # delete from beginning
    def delete_from_beginning(self):
        # check if empty:
        if self.is_empty():
            print('Cannot delete from Empty')
        # check if the list has a single element
        elif self.node_count() == 1:
            temp = self.head
            self.head = None
            self.tail = None
            del temp
        else: 
            # get reference to the head node
            current = self.head
            # shift head
            self.head = self.head.next
            # update prev of head
            self.head.prev = None
            # delete node
            del current
        
linked_list = DoublyLinkedList()
linked_list.append(10)
linked_list.append(80)
linked_list.append(9)
linked_list.append(11)
linked_list.append(14)
linked_list.traverse()
linked_list.delete_from_beginning()
linked_list.traverse()
# Out:
# None <-> 10 <-> 80 <-> 9 <-> 11 <-> 14 <-> None
# None <-> 80 <-> 9 <-> 11 <-> 14 <-> None

# %% [markdown]
# # Time Complexity for Delete First Node
# Assuming you have the node count beforehand, deleting the first node is independent of the size of the linked list. Hence,
#
# Time Complexity: O(1)
#
# Now, we will move to deletion from the end in a doubly linked list.

# %%
# Delete From The End

class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    #  traverse the linked list
    def traverse(self):
        current = self.head
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")

    # reverse traverse the linked list
    def reverse_traverse(self):
        current = self.tail
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")
    # node count
    def node_count(self):
        current = self.head
        count = 0
        while current is not None:
            count += 1
            current = current.next
        return count

    # check if empty
    def is_empty(self):
        return self.head == None

    # append to empty list
    def append_to_empty(self, data):
        new_node = Node(data)
        self.head = new_node
        self.tail = new_node

    # insert at the end(append)
    def append(self, data):
        if self.is_empty():
            self.append_to_empty(data)
            return
        new_node = Node(data)
        new_node.prev = self.tail
        self.tail.next = new_node
        self.tail = new_node
    
    # insert at beginning
    def insert_at_beginning(self, data):
        if self.is_empty():
            self.append_to_empty()
            return
        new_node = Node(data)
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node
    
    # insert at position
    def insert_at_position(self, position, data):
        if position < 0 or position > self.node_count():
            print("Invalid position")
            return
        elif position == 0:
            self.insert_at_beginning(data)
            return
        elif position == self.node_count():
            self.append(data)
            return
        else:
            new_node = Node(data)
            current = self.head
            for i in range(position - 1):
                current = current.next
            next_node = current.next
            current.next = new_node
            next_node.prev = new_node
            new_node.prev = current
            new_node.next = next_node

    # delete from beginning
    def delete_from_beginning(self):
        if self.is_empty():
            print('Cannot delete from Empty')
        elif self.node_count() == 1:
            temp = self.head
            self.head = None
            self.tail = None
            del temp
        else: 
            current = self.head
            self.head = self.head.next
            self.head.prev = None
            del current
    
    # delete from end
    def delete_from_end(self):
        # check if empty:
        if self.is_empty():
            print('Cannot delete from Empty')
        # check if the list has a single element
        elif self.node_count() == 1:
            temp = self.head
            self.head = None
            self.tail = None
            del temp
        else: 
            # get reference to the tail node
            current = self.tail
            # shift tail
            self.tail = self.tail.prev
            # update next of tail
            self.tail.next = None
            # delete node
            del current
            
linked_list = DoublyLinkedList()
linked_list.append(10)
linked_list.append(80)
linked_list.append(9)
linked_list.append(11)
linked_list.append(14)
linked_list.traverse()
linked_list.delete_from_end()
linked_list.traverse()
# Out:
# None <-> 10 <-> 80 <-> 9 <-> 11 <-> 14 <-> None
# None <-> 10 <-> 80 <-> 9 <-> 11 <-> None

# %% [markdown]
# # Time Complexity for Delete From End
# Assuming you have the node count beforehand, deleting the last node is independent of the size of the linked list. Hence,
#
# Time Complexity: O(1)

# %%
# Delete From Given Position

class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    #  traverse the linked list
    def traverse(self):
        current = self.head
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")

    # reverse traverse the linked list
    def reverse_traverse(self):
        current = self.tail
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")
    # node count
    def node_count(self):
        current = self.head
        count = 0
        while current is not None:
            count += 1
            current = current.next
        return count

    # check if empty
    def is_empty(self):
        return self.head == None

    # append to empty list
    def append_to_empty(self, data):
        new_node = Node(data)
        self.head = new_node
        self.tail = new_node

    # insert at the end(append)
    def append(self, data):
        if self.is_empty():
            self.append_to_empty(data)
            return
        new_node = Node(data)
        new_node.prev = self.tail
        self.tail.next = new_node
        self.tail = new_node
    
    # insert at beginning
    def insert_at_beginning(self, data):
        if self.is_empty():
            self.append_to_empty()
            return
        new_node = Node(data)
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node
    
    # insert at position
    def insert_at_position(self, position, data):
        if position < 0 or position > self.node_count():
            print("Invalid position")
            return
        elif position == 0:
            self.insert_at_beginning(data)
            return
        elif position == self.node_count():
            self.append(data)
            return
        else:
            new_node = Node(data)
            current = self.head
            for i in range(position - 1):
                current = current.next
            next_node = current.next
            current.next = new_node
            next_node.prev = new_node
            new_node.prev = current
            new_node.next = next_node

    # delete from beginning
    def delete_from_beginning(self):
        if self.is_empty():
            print('Cannot delete from Empty')
        elif self.node_count() == 1:
            temp = self.head
            self.head = None
            self.tail = None
            del temp
        else: 
            current = self.head
            self.head = self.head.next
            self.head.prev = None
            del current
    
    # delete from end
    def delete_from_end(self):
        if self.is_empty():
            print('Cannot delete from Empty')
        elif self.node_count() == 1:
            temp = self.head
            self.head = None
            self.tail = None
            del temp
        else: 
            current = self.tail
            self.tail = self.tail.prev
            self.tail.next = None
            del current

    # delete from given position 
    def delete_from_position(self, position):
        # check if the position is valid
        if self.is_empty():
            print('Cannot delete from Empty')  
        elif position <= 0 or position > self.node_count():
            print('Invalid position')
        elif position == 1:
            self.delete_from_beginning()
        elif position == self.node_count():
            self.delete_from_end()
        else:
            # get reference to the nodes before and after the given position. 
            current = self.head
            prev_node = next_node = None
            for i in range(position-1):
                current = current.next
            prev_node = current.prev
            next_node = current.next

            # update pointers
            prev_node.next = next_node
            next_node.prev = prev_node

            # delete node
            del current

linked_list = DoublyLinkedList()
linked_list.append(10)
linked_list.append(80)
linked_list.append(9)
linked_list.append(11)
linked_list.append(14)
linked_list.traverse()
linked_list.delete_from_position(4)
linked_list.traverse()
# Out:
# None <-> 10 <-> 80 <-> 9 <-> 11 <-> 14 <-> None
# None <-> 10 <-> 80 <-> 9 <-> 14 <-> None

# %% [markdown]
# # Time Complexity for Delete From Given Position
# To delete nodes at a given position, you may need to traverse the entire linked list. Hence,
#
# Time Complexity: O(n)

# %%
# Complete Doubly Linked List
# We have learnt to:

# Create a linked list
# Traverse a linked list
# Insert values in linked list
# Delete values from linked list

# Now, let's combine all the code and see how the complete linked list code looks like:


class Node:
    def __init__(self, data):
        self.prev = None
        self.data = data
        self.next = None
 
class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
 
    #  traverse the linked list
    def traverse(self):
        current = self.head
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.next
        print("None")
 
    # reverse traverse the linked list
    def reverse_traverse(self):
        current = self.tail
        print("None", end = " <-> ")
        while current is not None:
            print(f"{current.data} <-> ", end="") 
            current = current.prev
        print("None")
    # node count
    def node_count(self):
        current = self.head
        count = 0
        while current is not None:
            count += 1
            current = current.next
        return count
 
    # check if empty
    def is_empty(self):
        return self.head == None
 
    # append to empty list
    def append_to_empty(self, data):
        new_node = Node(data)
        self.head = new_node
        self.tail = new_node
 
    # insert at the end(append)
    def append(self, data):
        if self.is_empty():
            self.append_to_empty(data)
            return
        new_node = Node(data)
        new_node.prev = self.tail
        self.tail.next = new_node
        self.tail = new_node
    
    # insert at beginning
    def insert_at_beginning(self, data):
        if self.is_empty():
            self.append_to_empty()
            return
        new_node = Node(data)
        new_node.next = self.head
        self.head.prev = new_node
        self.head = new_node
    
    # insert at position
    def insert_at_position(self, position, data):
        if position < 0 or position > self.node_count():
            print("Invalid position")
            return
        elif position == 0:
            self.insert_at_beginning(data)
            return
        elif position == self.node_count():
            self.append(data)
            return
        else:
            new_node = Node(data)
            current = self.head
            for i in range(position - 1):
                current = current.next
            next_node = current.next
            current.next = new_node
            next_node.prev = new_node
            new_node.prev = current
            new_node.next = next_node
 
    # delete from beginning
    def delete_from_beginning(self):
        if self.is_empty():
            print('Cannot delete from Empty')
        elif self.node_count() == 1:
            temp = self.head
            self.head = None
            self.tail = None
            del temp
        else: 
            current = self.head
            self.head = self.head.next
            self.head.prev = None
            del current
    
    # delete from end
    def delete_from_end(self):
        if self.is_empty():
            print('Cannot delete from Empty')
        elif self.node_count() == 1:
            temp = self.head
            self.head = None
            self.tail = None
            del temp
        else: 
            current = self.tail
            self.tail = self.tail.prev
            self.tail.next = None
            del current
 
    # delete from given position 
    def delete_from_position(self, position):
        if self.is_empty():
            print('Cannot delete from Empty')  
        elif position <= 0 or position > self.node_count():
            print('Invalid position')
        elif position == 1:
            self.delete_from_beginning()
        elif position == self.node_count():
            self.delete_from_end()
        else:
            current = self.head
            prev_node = next_node = None
            for i in range(position-1):
                current = current.next
            prev_node = current.prev
            next_node = current.next
            prev_node.next = next_node
            next_node.prev = prev_node
            del current
 
linked_list = DoublyLinkedList()
linked_list.append_to_empty(2)
linked_list.append(4)
linked_list.insert_at_beginning(1)
linked_list.insert_at_position(2, 3)
linked_list.traverse()
 
linked_list.delete_from_position(2)
linked_list.delete_from_beginning()
linked_list.delete_from_end()
linked_list.traverse()
# Out:
# None <-> 1 <-> 2 <-> 3 <-> 4 <-> None
# None <-> 3 <-> None
